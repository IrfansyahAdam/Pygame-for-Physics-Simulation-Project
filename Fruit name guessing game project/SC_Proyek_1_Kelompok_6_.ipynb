# %%
print('Permainan Tebak Nama Buah')
print('Oleh : Muhammad Irfansyah Adam (1306622055)')
print('       Moh Taofik Ubaidilah    (1306622063)')
print('       Auliya Rahmawati        (1306622024)')

import random

print()
buah = ['anggur', 'apel', 'aprikot', 'asam', 'atap', 'arbei', 'abiu', 'alpukat', 'anjeng', 'bacang', 'baguk', 'belimbing', 'bengkuang', 'benda', 'binjai', 'bisbul', 'blueberry', 'burahol', 'blewah', 'bit', 'cempedak', 'ceplukan', 'cermai', 'ceri', 'cokelat', 'delima', 'duku', 'durian', 'duwet', 'enau', 'enamenam', 'frambos', 'hamoi', 'hamlam', 'holdi', 'jamblang', 'jambuair', 'jambubatu', 'jambubol', 'jambumawar', 'jambumede', 'jengkol', 'jeruk', 'jerukbali', 'jerukkeprok', 'jerukkingkit', 'jeruknipis', 'jerukpurut', 'kapulasan', 'kawista', 'kecapi', 'kedondong', 'kelapa', 'kelengkeng', 'kelubi', 'ketela', 'kemang', 'kepel', 'kersen', 'kesemek', 'kokosan', 'kiwi',
'koldi', 'kurma', 'kelawi', 'kenitu', 'lai', 'langsat', 'lemon', 'leci', 'lobak', 'maja', 'malaka', 'mangga', 'manggis', 'markisa', 'melon', 'mengkudu', 'menteng', 'matoa', 'mentimun', 'namnam', 'nanas', 'nangka', 'naga', 'nona', 'pepaya', 'persik', 'pir', 'pisang', 'pete', 'rambai', 'rambusa', 'rambutan', 'rukem', 'sawo', 'semangka', 'sirsak', 'siwalan', 'srikaya', 'stroberi', 'sukun', 'terap', 'terong', 'tomat', 'timunsuri', 'ubi', 'waluh', 'wuni', 'zaitun'
]

while True:
    buah_terpilih = random.choice(buah)
    jumlah_huruf = len(buah_terpilih)
    nyawa = jumlah_huruf
    tebakan = ["_"] * jumlah_huruf

    print("       SELAMAT DATANG DI PERMAINAN TEBAK BUAH!!!")
    print()
    print(f"Aku udah milihin satu buah dengan {jumlah_huruf} huruf. Coba tebak dongg buah apa yaa??.")
    print()
    while nyawa > 0 and "_" in tebakan:
        tebakan_pemain = input(f"Tebakan kamu ({nyawa} nyawa tersisa): ").lower()

        if not tebakan_pemain.isalpha() or len(tebakan_pemain) != 1:
            print("Masukkan satu huruf alfabet ajaa.")
            continue
            print()

        tebakan_benar = False
        for i in range(jumlah_huruf):
            if buah_terpilih[i] == tebakan_pemain:
                tebakan[i] = buah_terpilih[i]
                tebakan_benar = True

        if tebakan_benar:
            print("asikk tebakan kamu benarr!")
            print("Huruf yang udah kamu tebak: " + " ".join(tebakan))
            print()
        else:
            nyawa -= 1
            print(f"yahh salahh, {tebakan_pemain} itu gaadaa. sisa nyawamu: " + str(nyawa))
            print("Huruf yang udah kamu tebak: " + " ".join(tebakan))
            print()
    if "_" not in tebakan:
        print(f"Wahh Selamattt! kamu berhasil menebak buah {buah_terpilih} dengan benar.")
        print()
    else:
        print(f"yahahah gagal. Buah yang benar adalah {buah_terpilih}.")
        print()
    ingin_bermain_lagi = input("Mau main lagi kahh?? (y/t): ").lower()
    if ingin_bermain_lagi != 'y':
        print("Terima kasih telah bermain!!")
        break
# Out:
# Permainan Tebak Nama Buah
# Oleh : Muhammad Irfansyah Adam (1306622055)
#        Moh Taofik Ubaidilah    (1306622063)
#        Auliya Rahmawati        (1306622024)
#
#        SELAMAT DATANG DI PERMAINAN TEBAK BUAH!!!
#
# Aku udah milihin satu buah dengan 5 huruf. Coba tebak dongg buah apa yaa??.
#
# Tebakan kamu (5 nyawa tersisa): u
# yahh salahh, u itu gaadaa. sisa nyawamu: 4
# Huruf yang udah kamu tebak: _ _ _ _ _
#
# Tebakan kamu (4 nyawa tersisa): a
# yahh salahh, a itu gaadaa. sisa nyawamu: 3
# Huruf yang udah kamu tebak: _ _ _ _ _
#
# Tebakan kamu (3 nyawa tersisa): m
# asikk tebakan kamu benarr!
# Huruf yang udah kamu tebak: m _ _ _ _
#
# Tebakan kamu (3 nyawa tersisa): i
# yahh salahh, i itu gaadaa. sisa nyawamu: 2
# Huruf yang udah kamu tebak: m _ _ _ _
#
# Tebakan kamu (2 nyawa tersisa): e
# asikk tebakan kamu benarr!
# Huruf yang udah kamu tebak: m e _ _ _
#
# Tebakan kamu (2 nyawa tersisa): n
# asikk tebakan kamu benarr!
# Huruf yang udah kamu tebak: m e _ _ n
#
# ...
